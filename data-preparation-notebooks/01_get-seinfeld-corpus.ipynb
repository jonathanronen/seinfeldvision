# %%
# !pip install html2text
# Out:
# Collecting html2text
#   Downloading https://files.pythonhosted.org/packages/16/20/de2b458ef434713053dd83209a03a5431ebe0527c8e14d9ae7838ff67d8a/html2text-2018.1.9-py3-none-any.whl
# Installing collected packages: html2text
# Successfully installed html2text-2018.1.9

# %%
import re
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

from tqdm import tqdm, tqdm_notebook
import html2text

from itertools import chain
from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

import textwrap

# %%
resp = get('http://www.seinfeldscripts.com/seinfeld-scripts.html', headers={"content-type":"text/html", "User-Agent": "Mozilla Firefox"})
resp.close()
resp
# Out:
# <Response [200]>

# %%
html = BeautifulSoup(resp.content, 'html.parser')

# %%
episode_names, episode_urls = zip(*[(e.text.replace('\n',''), 'http://seinfeldscripts.com/{}'.format(e.attrs['href'].strip())) for e in html.select('table:nth-of-type(2) a') ])
len(episode_urls)
# Out:
# 180

# %%
all_episodes_raw_htmls = list()
for url in tqdm_notebook(episode_urls):
  try:
    resp = get(url, headers={'content-type': 'text/html;', 'User-Agent': 'Mozilla Firefox'})
    if not resp.ok:
      resp.close()
      print(f"Failed at episode number {i} ({e})")
    all_episodes_raw_htmls.append(resp.content)
  finally:
    resp.close()
# Out:
# HBox(children=(IntProgress(value=0, max=180), HTML(value='')))

# %%
h = html2text.HTML2Text()
h.ignore_emphasis = True
h.ignore_images = True
h.ignore_links = True
h.ignore_tables = True

# %%
raw_texts = list()
for raw_html in tqdm_notebook(all_episodes_raw_htmls):
  raw_texts.append(h.handle(raw_html.decode()).strip().split('\n'))
# Out:
# HBox(children=(IntProgress(value=0, max=180), HTML(value='')))

# %%
# c = Counter()
# for episode in raw_texts:
#   c.update(episode)
# c.most_common(10)

c = Counter(l for episode in raw_texts for l in episode)
c.most_common(10)
# Out:
# [('', 62594),
#  ('  ', 21522),
#  ('    ', 369),
#  ('JERRY', 344),
#  ('(Scene ends)', 258),
#  ('ELAINE', 256),
#  ('KRAMER', 238),
#  ('New scene.  ', 210),
#  ('GEORGE', 185),
#  ('Looking for a great gift idea for the holidays?  ', 182)]

# %%
# sum(1 for e,ct in c.items() if ct>1 )
ser = pd.Series(list(c.values()))
ser.describe()
# Out:
# count    84805.000000
# mean         2.189317
# std        227.322782
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max      62594.000000
# dtype: float64

# %%
{e for e,ct in c.items() if ct>3 and ct < 10 and not re.match('([a-z])+: ', e.lower().strip()) }
# Out:
# {'"Well,',
#  '% Opening monologue',
#  "'ting' of a microwave.",
#  '(Enter Kramer)',
#  '(George enters)',
#  '(George enters)  ',
#  '(Kramer enters the apartment)',
#  '(Kramer walks in)',
#  '(Scene ends.)',
#  '(Scene: At Elaine\x92s apartment)',
#  '(Scene: At Jerry\x92s apartment)',
#  "(Scene: Jerry's Apartment)  ",
#  '(commercial)',
#  '(end of flashback)',
#  "(hurriedly) Why d'you wear the same dress all the time? Hello.",
#  "(listens) Oh really? Well you can't break up with me over the phone.",
#  '(phone rings)',
#  '(pointedly) By myself.',
#  '*knock, knock, knock*',
#  '.',
#  '...',
#  '<Elaine enters>',
#  '<Spellchecked and reformatted by Mike "The News Guy">  ',
#  '<break>',
#  '=========  ',
#  '==================',
#  '========================================',
#  '=============================================================',
#  '================================================================',
#  '========================================================================',
#  '===========================================================================',
#  'A kid leans out the window of a parked Volvo.',
#  'A member of staff approaches.',
#  'A sandwich of epic proportions. He hums to himself as he piles sliced',
#  'ACT ONE',
#  'ALLISON',
#  'AMANDA',
#  'Advertisement',
#  'Along the sidewalk comes a happy-looking Newman, pedalling the Schwinn',
#  'Around beautiful name, it is also a living tribute.',
#  'As George speaks, Ken is looking impatient and angry.',
#  "At Monk's.",
#  'Barney Martin (Morty Seinfeld)  ',
#  "C'mon, you gotta do this in person. It doesn't even have to be one on one, you",
#  'CUT TO:',
#  "Carrie is in a wheelchair, being wheeled by an orderly. She's doing her",
#  'Carrie is on the couch, with Ken sitting on the arm. George is',
#  'Carrie jumps and gives a cry.',
#  'Carrie look perturbed.',
#  'Cast:  ',
#  'Cheryl Hunter (Woman)',
#  'Christie adds a little pepper to her dish. But after replacing the',
#  'Christie begins to season her food, with salt. Jerry chews',
#  'Christie comes over to Elaine. All Elaine can see of her is her head',
#  'Christie is looking in a shop window, then she spots Elaine.',
#  'Christie leads Jerry into her home.',
#  'Christie leaves her examination of the toys on that side of the store,',
#  "Christie mops at the spill with her napkin, but there's only so much",
#  'Christie puts down her bag, and removes her coat.',
#  'Christie walks away down a hallway. Jerry removes his coat and sits',
#  'Christie walks away.',
#  'Christie.',
#  'Closing monologue.  ',
#  'Commercial  ',
#  "Costanza, that's original. (he turns and sees another item) Or uh, Ketchup?",
#  'DOCTOR',
#  'Defeated, Jerry hangs up the phone.',
#  "Destroy someone else's.",
#  'Dijon.',
#  'Directed by: Tom Cherones  ',
#  'ELAINE (O.C.): (angry shout) Kramer!',
#  'END',
#  'END  ',
#  'EXT. CITY SIDEWALK - DAY',
#  'EXT. CITY STREET - DAY',
#  "EXT. JERRY'S APARTMENT - DAY - ESTABLISHING",
#  'Elaine Benes ......................... Julia Louis-Dreyfus',
#  'Elaine Benes Julia Louis-Drefus',
#  'Elaine Benes Julia Louis-Dreyfus',
#  'Elaine and Jerry enter a store stocked with the toys of yesteryear.',
#  "Elaine and Kramer sit on Newman's couch. Elaine with her head tilted",
#  "Elaine and Kramer still sit on the couch, awaiting Newman's",
#  'Elaine collides with a litter bin which is outside her field of vision.',
#  'Elaine comes by with that bike, you hang onto it for me, alright?',
#  "Elaine enters Jerry's apartment.",
#  'Elaine enters.  ',
#  "Elaine enters. She has her head leaning over to the left, and she's",
#  'Elaine gives up on Jerry assisting her and tries to lift the bike off',
#  "Elaine grabs hold of the trailing end of Newman's scarf.",
#  'Elaine is in bed. She begins to move to get up. As she raises herself',
#  'Elaine is walking along, when she spots something ahead of her.',
#  "Elaine makes 'So, are you gonna help me?' gestures.",
#  'Elaine reaches for the bike, as Jerry turns back to Christie.',
#  'Elaine removes her bag from her back, wincing from the pain as she',
#  'Elaine rolls her head around, completely comfortable.',
#  'Elaine slams the door shut before Kramer can leave. Kramer rides',
#  'Elaine turns to Jerry and gets a twinge from her neck.',
#  'Elaine walks along the street. Her neck problem means she has her head',
#  'Elaine!',
#  "Elaine, handicapped by her neck, cannot see who's speaking.",
#  'Elaine.',
#  'End',
#  'End of episode.',
#  'End of episode.  ',
#  'Executive Producer ................... Andrew Sherman',
#  'FELDMAN',
#  'Fastened to the collar.',
#  'Fill in later...',
#  'Fingers his chin thoughtfully.',
#  'GENE',
#  'George Castanza ...................... Jason Alexander',
#  'George Costanza Jason Alexander',
#  'George and Susan are having dinner with Ken and Carrie. Carrie is',
#  'George and Susan are having dinner.',
#  'George and Susan, heading home from the restaurant. George is happy,',
#  'George closes the door behind him.',
#  'George enters',
#  'George enters.',
#  'George flashes a panicked expression.',
#  "George gives Jerry a look. Kramer enters. He's carrying a small",
#  'George has fetched a Diet Coke from the fridge. He opens it. Kramer',
#  'George laughs and shovels another load of pasta into his mouth. Ken and',
#  'George passes by as he goes to the fridge.',
#  "George thumps his fists against the door in frustration. He's crying as",
#  'George trails along behind them, making suggestions.',
#  'George tries to follow, but an orderly blocks his path.',
#  'George uses his finger to draw a number 7 in the air, accompanying the',
#  "George walks away, half-laughing at Jerry's ludicrous suggestion.",
#  'George walks up to the door. He pushes the buzzer for a particular',
#  'George)',
#  'George.  ',
#  'Guest stars:  ',
#  'He screams.',
#  "Healing power of the body's natural pressure points.",
#  'Heavily pregnant. George is eating spaghetti with his usual decorum.',
#  'Hey.',
#  'I',
#  'I made it up!',
#  "I'll add that later.",
#  "I'm gonna help you out. You want a beautiful name? Soda.",
#  "INT. ELAINE'S APARTMENT - DAY",
#  "INT. J. PETERMAN'S OFFICE - DAY",
#  "INT. JERRY'S APARTMENT - DAY",
#  "INT. JERRY'S CAR - DAY",
#  "IT'S A CLIP SHOW - THERE'S NO SCRIPT",
#  'Impression of limitless wisdom.',
#  "It's very unusual.",
#  'JERRY (V.O.): August seventeen, nineteen-ninety-two. The same dress!',
#  'JERRY (V.O.): There must be a secret stash around here somewhere.',
#  "JERRY (V.O.): What in god's name is going on here? Is she wearing the",
#  'Jason Alexander .................. George Costanza  ',
#  'Jason Alexander.................. George Costanza',
#  'Jerry Seinfeld ....................... Jerry Seinfeld  ',
#  'Jerry Seinfeld ....................... Jerry Seinfeld (well, duh!)',
#  'Jerry Seinfeld Jerry Seinfeld (well, duh!)',
#  'Jerry Seinfeld................... Jerry Seinfeld',
#  'Jerry Seinfeld....................... Jerry Seinfeld  ',
#  'Jerry and Christie are having dinner. Christie is eating, while Jerry',
#  "Jerry and Christie have just arrived. They're both wearing long coats,",
#  'Jerry and George are at the coffee shop.  ',
#  'Jerry and George sit in a booth, discussing the previous night. George',
#  'Jerry clicks.  ',
#  'Jerry comes back into the living room. A thought occurs.',
#  'Jerry gets up from his seat.',
#  'Jerry hears a loud knocking from the hallway.',
#  'Jerry hold up a half banana.',
#  'Jerry holds up an apple, from which has been taken one large bite.',
#  'Jerry is in the fridge. Kramer enters with a slide of the feet, and a',
#  'Jerry is in the kitchen, and opens a cupboard. His eyes run over the',
#  'Jerry is on the phone, while Kramer examines a box of cereal in the',
#  'Jerry looks over, but his eye is drawn more towards an attractive',
#  'Jerry moves to the couch, where he half lays down.',
#  "Jerry opens a closet and begins to look inside. While he's rooting",
#  "Jerry opens the door to reveal Elaine hammering insistently at Kramer's",
#  'Jerry picks up his coat and moves toward the door.',
#  'Jerry sits in front of the TV, while in the kitchen Kramer is building',
#  "Jerry takes back the tab, then takes the cereal out of Kramer's hands.",
#  'Jerry tears a sheet off a writing pad, and presents it to Kramer.',
#  "Jerry walks from the bathroom, talking to George, who's just told him",
#  "Jerry walks though the door. He's still talking as Christie closes it",
#  'Jerry walks toward the kitchen. He sees an item on the counter.',
#  "Jerry's Apartment",
#  "Jerry's apartment. He rides all around the apartment, round the couch, past",
#  "Jerry's standup piece.",
#  "Jerry's standup piece.  ",
#  'Jerry.  ',
#  'Jerry. I had this name for a long time.',
#  'Julia Louis-Dreyfus.............. Elaine Benes',
#  'KEN (O.C.): Hello.',
#  'KRAMER & MICKEY: Rock, paper, scissors match.  ',
#  'Ken and Carrie rise and head toward the door.',
#  'Ken gives him a look over his shoulder.',
#  'Ken grabs the suitcase from by the door and they exit, hurriedly.',
#  'Ken has left, George follows out the door.',
#  "Ken is driving Carrie to the hospital. Carrie is as worked up as you'd",
#  'Ken strides into the delivery room.',
#  'Knock , knock',
#  'Kramer  ',
#  'Kramer - Michael Richards',
#  'Kramer Michael Richards',
#  "Kramer begins to work at Elaine's neck with his thumbs.",
#  'Kramer brings his first hand down to the level of the second. He',
#  'Kramer comes along the street, riding the Schwinn Stingray and ringing',
#  'Kramer enters',
#  'Kramer goes back to his sandwich, puts the second slice of bread on,',
#  'Kramer goes to the fridge and looks inside.',
#  'Kramer heads for the door.',
#  'Kramer heads toward the door.',
#  'Kramer holds his other hand at about knee height.',
#  'Kramer holds one hand up above his head.',
#  'Kramer leans forward to receive the result. Elaine looks as attentive',
#  'Kramer leaves and closes the door again.',
#  'Kramer leaves at a run.',
#  'Kramer leaves.',
#  'Kramer looks at Elaine, thinking his arguments have put him one up.',
#  'Kramer opens the door and rides clumsily out, ringing the bell as he',
#  'Kramer picks up the bike and climbs aboard.',
#  'Kramer takes a cupcake from a box on the counter.',
#  "Kramer takes a firm grip of each side of Elaine's head. Elaine looks",
#  'Kramer takes a look.',
#  'Kramer thumbs his nose and continues pedalling.',
#  "Kramer violently twists Elaine's head to the left. There's a loud",
#  'Kramer walks around behind the seated Elaine, and reaches for her neck.',
#  'Kramer waves away the squeezy option and shuts the fridge.',
#  "Kramer's demolishing his food stocks.",
#  'LELAND',
#  'Liz Sheridan (Helen Seinfeld)  ',
#  "Look at this! Look! Ow. I couldn't even crawl out of bed this morning.",
#  "MAITRE D': May I take your coat, miss?",
#  "MOHEL (CONT'D)",
#  'Mantle that I would name my baby Seven.',
#  'Matter how unjust it may seem to either of you. Do I have your word?',
#  'Monks',
#  "Moving carefully, like it's giving her pain.",
#  'Mrs. SWEEDLER',
#  'NOREEN',
#  'Net reaction and comments:',
#  'Newman begins to ride away.',
#  'Newman brakes to a halt in front of Elaine.',
#  'Newman catches himself, and comes back to normality.',
#  'Newman leaps to his feet and heads for his kitchen.',
#  'Newman sits back, to begin his contemplation. There is the single',
#  "Newman's face drops at her negative reaction. Kramer looks across at",
#  'No, I said mustard, Jerry. Dijon.',
#  'No.',
#  'Not for any man...',
#  'OK, so maybe a small introduction.',
#  'Of reliability? Hmm? Huh? Ahh. These were not easy questions to answer.',
#  "On these, you can't expect me to pay for the whole box.",
#  'Opening scene.  ',
#  'Pimento. Gherkin. Sauce. Maxwell House.',
#  'Pretty name for a girl.',
#  'Previous episode references:',
#  'Quotes and Scene summary:',
#  'Real original. You wanna hear what it is? Huh, you ready?',
#  "Really worried now. She grabs a hold of Jerry's shirt and the arm of the",
#  'Recurring Cast:  ',
#  'Refrigerator problem, is solved.',
#  'Regulars:',
#  'Resident',
#  'Say "Hey, nice person." It\'s much easier to be a bastard and just try and',
#  'Scene  ',
#  'She never',
#  "Smorgasbord here, but it's the end of the week, so I added up your tab.",
#  'Soda.',
#  "Something on the wall catches Elaine's eye. It's an old-fashioned",
#  'Strokes of his digit with a two-tone whistle.',
#  "Superman? I've got to unlock this mystery.",
#  'Supervising Producer ................. Larry Charles',
#  'Susan scoffs.',
#  'TV and is heading for the door.',
#  'Telling me people loved the name Blanche the first time they heard it?',
#  "That's like half a pound of turkey!",
#  "The Maitre d' helps Christie to slip out of her coat, revealing that",
#  "The couch. Then in the morning, you'll get dressed, we'll walk out",
#  'The orderly closes the door on George, whose face can be seen through',
#  'The orderly pushes the wheelchair on through the door of the delivery',
#  'The show ends with a freeze frame of Newman on the bike, and a',
#  "The wedding. Who knows if you'll ever get married.",
#  'The window.',
#  "There's a ringing from the Schwinn's bell, and Kramer rides it into",
#  'They look around at the array of classic teddy bears, toy boats, puppets, etc.',
#  "Tipped back so far she can't see directly in front of her. A guy coming the",
#  'Transcribed by: (Mazzy) Mark Brockbank Barrow-in-Furness, UK  ',
#  'Transcribed by: Matt Dittloff',
#  "VOICE 1 (O.C.): Lookin' good.",
#  'VOICE 2 (O.C.): Hey Cosmo, nice wheels.',
#  'Wanted from your fridge, and you could take whatever you want from mine.',
#  'What?',
#  'White dress. Jerry picks it up and examines it more closely, reading a date',
#  'Written by: Gregg Kavet & Andy Robin  ',
#  'Written by: Larry Charles  ',
#  'Written by: Larry David',
#  'Written by: Larry David  ',
#  'Written by: Larry David and Jerry Seinfeld',
#  'Written by: Peter Mehlman  ',
#  'Written by: Tom Gammill & Max Pross  ',
#  'Yeah.',
#  'Yes.',
#  "You'll",
#  '[Airport]  ',
#  '[Alex Theatre: Lobby]',
#  '[Antique Toy Store]',
#  '[Back in the courtroom]',
#  '[Back to the courtroom]',
#  "[Christie's Apartment]",
#  '[Commercial Break]',
#  '[Costanza House]  ',
#  '[Eighty-sixth Street]  ',
#  '[Elaine comes in.]',
#  '[Elaine enters]',
#  "[Elaine's Apartment]  ",
#  "[Elaine's Office, J. Peterman]  ",
#  "[Elaine's Office]  ",
#  "[Elaine's]",
#  '[End]',
#  '[George enters]',
#  "[George's Car]",
#  "[George's car]  ",
#  "[George's parents' house]  ",
#  '[Hospital]',
#  "[Jenna's Apartment]  ",
#  "[Ken and Carrie's Apartment]",
#  "[Ken and Carrie's Car]",
#  '[Kramer comes in.]',
#  '[Kramer enters]  ',
#  "[Lobby, Jerry's Building]",
#  "[Lobby, Mr. Pitt's Building]  ",
#  '[Mail Truck]  ',
#  "[Monks']",
#  '[Monks]',
#  "[Morty and Helen's, Florida]  ",
#  "[Mr. Pitt's office]",
#  "[Newman's Apartment]",
#  '[Nightclub]',
#  '[Nightclub]  ',
#  '[Opening Monologue]',
#  '[Outside Apartment Building]',
#  '[Phone rings]',
#  '[Putumayo]  ',
#  '[Restaurant]  ',
#  '[Royal Bakery]',
#  "[Rudy's Antique Boutique]  ",
#  '[Scene: Comedy club]',
#  '[Setting: Bookstore]',
#  '[Setting: Coffee Shop]',
#  '[Setting: Dealership car]',
#  "[Setting: Elaine's office]",
#  "[Setting: George's old bedroom]",
#  '[Setting: H&H Bagel Shop]',
#  "[Setting: Jerry's car]",
#  '[Setting: NYC Street]',
#  "[Setting: Newman's apartment]",
#  '[Setting: Nightclub]',
#  '[Setting: The Coffee shop]',
#  "[Steinbrenner's office]",
#  '[Street Corner]  ',
#  '[Street Outside Alex]',
#  '[Subway train]  ',
#  '[The Costanza Home, Queens]  ',
#  '[Theatre]  ',
#  '[Transcribed by Dave (ratboy)]  ',
#  "[Valerie's Apartment]  ",
#  '[Yankee Stadium]',
#  '[clip clop]',
#  "[location: Jerry's apartment]",
#  "[setting: Jerry's]",
#  "[setting: Monk's]",
#  '[setting: Rinitze]',
#  '\\----------------------------------------------------',
#  '\\--------------------------------------------------------',
#  '\\---------------------------------------------------------',
#  '\\--------------------------------------------------------------',
#  '\\------------------------------------------------------------------  ',
#  '\\----------------------------------------------------------------------',
#  '\\-------------------------------------------------------------------------------',
#  'about his contretemps with Susan.',
#  'about in there, Christie reenters the room, wearing a robe and looking',
#  'all  ',
#  'all its cachet!',
#  'all up, and you give me the bill.',
#  "all we have. (getting worked up) It's all that separates us from the savages",
#  'and I will.',
#  'and arms.',
#  'and neck.',
#  'and now you have the bike?!',
#  "and smiles and flirtatious looks are exchanged. Jerry is oblivious to Elaine's",
#  "and takes a bite. It doesn't meet with his approval. He spits out the mouthful",
#  'and walks over to some other items. Jerry watches her as she goes, she notices',
#  "antique store. What's her name, Christie?",
#  'any kind.',
#  'anyone who fixes your neck.',
#  'anything.',
#  'arbitration.',
#  'array of good within.',
#  'as she can while only being able to look upwards.',
#  'assurance',
#  'at discovering Jerry invading her privacy.',
#  'at our word, all is lost.',
#  'attempt to save his name.',
#  'back',
#  'back to my apartment, so I can change?',
#  'back.',
#  'back.  ',
#  'back. Newman sits in his chair, his fingertips together, trying to give an',
#  'be named Seven!',
#  'bed.',
#  'beef?',
#  'before.',
#  'before. Someone who is unencumbered by any emotional attachment. Someone whose',
#  'best in the city.',
#  'bike down the middle, and give half to each of you.',
#  'bowl) There. Very simple.',
#  'breathing. Ken hurries alongside, comforting his wife. George also',
#  "bring a group of friends. I just wanna see you. Wait, don't hang up on me.",
#  'building.',
#  'can',
#  'can see that. Even Jerry. But not you, Elaine...',
#  'cash. Fifty bucks! (he laughs) Can you believe it? Of course, I had to make',
#  "changes! Oh my god. (looking around) She's gotta have hundreds of these",
#  'chest',
#  'cigar in his mouth.',
#  'clean and she started all over again.',
#  'compensation. But, does the fee, once paid, not entitle the buyer to some',
#  'conscience. There',
#  'couch, and her feet stamp on the floor.',
#  "cousins. So your baby daughter is gonna be Susan's second cousin, right? So",
#  'crazy on me!',
#  'determined Elaine grasping the scarf. There are sounds of a struggle.',
#  'directed by: Andy Ackerman',
#  'do.',
#  'does that make me?',
#  'door.',
#  'door.  ',
#  'down. He looks around himself. On the coffee table he notices a small framed',
#  "down. She struggles to lift it, but can't make much impression, so she rings",
#  'downstairs, me in my same clothes, you in your different clothes.',
#  'dresses.',
#  'duty',
#  'else is gonna have it and I absolutely love it.',
#  'enters)',
#  'everything.',
#  'expect a woman in labor to be. In the back seat, George is making one last',
#  'expectantly.',
#  'explaining about Seven.',
#  'face.',
#  'face.  ',
#  'falls backwards, ending up on her back on the floor with the bike pinning her',
#  'favourites on hand.',
#  "for all he's worth. He rings the bell.",
#  'for me.',
#  'for this, okay...',
#  'fridge?',
#  'from the mattress, there is a loud crunching sound. A look of agony crosses',
#  'get',
#  'gets it from his butcher.',
#  'gimme...',
#  "girl's bicycle, with high handlebars, a pink frame and a basket on the front.",
#  'give it away than see it come to harm. Kramer, the bike is yours!',
#  'goes.',
#  'goldfish bowl, a pad and a pencil tied to the bowl by string.',
#  'gonna come',
#  'got',
#  'has  ',
#  'has a legitimate claim to the bicycle, and yet the bicycle can have only one',
#  'have  ',
#  'have the bike.',
#  'he  ',
#  "he's",
#  'hears the hiss, and notices George.',
#  'heart is so dark, it cannot be swayed by pity, compassion, or human emotion of',
#  'hell up?',
#  'her',
#  'her.',
#  'here!',
#  'here.',
#  'here.  ',
#  'here?',
#  'him.',
#  'his',
#  'hospital...',
#  'huh?',
#  'hurting me,',
#  'hustles along the corridor with the group.',
#  'in',
#  'in  ',
#  'in half.',
#  'indignant',
#  "into mailboxes where they don't belong!!...",
#  'involved. What you need is an impartial mediator.',
#  'is',
#  'is  ',
#  'is a brief pause, then the door opens again and Kramer pokes in his head,',
#  'it  ',
#  'it out.',
#  'it!',
#  'it...',
#  'just  ',
#  'kitchen.',
#  "knack for moving pieces of a person's spine around.",
#  'know',
#  "know why you ant it. (laughingly) I mean, it's a girl's bike.",
#  'know,',
#  'lay it out on the bed.',
#  'leans back picking at his meal, looking suspicious at the fact that Christie',
#  'leaves, closing the door with a bang. Elaine sits, fighting with her',
#  'looks bemused, but plasters on a fixed smile as Christie looks at him.',
#  'match the colours up.',
#  'me.',
#  'me.  ',
#  'meat onto bread. Jerry looks over at him, looking somewhat irritated by the',
#  'mid-thigh length, black from the bottom of the ribs down, and white on the',
#  'minutes.',
#  "minutes. And, don't eat any more.",
#  'model! Oh, I always wanted one of these when I was little.',
#  'moves.',
#  'my neck.',
#  'neck. She looked like some kinda superhero.',
#  'now.',
#  'of',
#  "of course be in different clothes, because it's your apartment. But we'll go",
#  'off  ',
#  'off.',
#  'office.',
#  'on',
#  'on  ',
#  'on him.',
#  'one hand, Elaine, your promise was given in haste. But was it not still a',
#  'one.  ',
#  'other way gives her a warning.',
#  'out!',
#  'out.  ',
#  'paediatrics.',
#  'parcels',
#  "picture of Christie and some guy. In the picture, she's wearing the same black",
#  'place.',
#  'problem.',
#  'promise? Hmm?',
#  'put it in the bowl. (he tears off the sheet, crumples it and drops it into the',
#  "qualities. Right? Let's face it, no matter how nice a person you are, nobody's",
#  'refreshing!',
#  'right?',
#  'rightful owner. Quite the conundrum. As a federal employee, I believe the law',
#  'room.',
#  'room. Ken turns to face George.',
#  'same thing over and over again? Or does she have a closet full of these, like',
#  'say?',
#  'saying,',
#  'school, seven beatings a day. Roughly seven stitches a beating, and eventually',
#  'settle this.',
#  "seven years to life. Yeah, you're doing that child quite a service.",
#  'shaker, she knocks her glass of red wine over her dress.',
#  'she has on the exact same dress as she was wearing in the antique store. Jerry',
#  'shocks. But, baby, this is one sweet ride.',
#  'smiling and whistling.',
#  'something.  ',
#  'steps away, job done.',
#  'straight into the door with a clatter. He falls to the ground, then makes his',
#  'stumbling way upright again.',
#  'table)',
#  'table.',
#  'taken onto the plate, and dumps the rest of the sandwich next to it.',
#  'than Seven.',
#  'than see it destroyed. Newman, give it to her, I beg you.',
#  'thank you. Thank you very much." The compliment is for the tie, it\'s not for',
#  'that',
#  'that  ',
#  'that.',
#  'that?',
#  'that?  ',
#  'the bell on the bike. Jerry finally has his attention drawn away from',
#  'the bell. He attracts comments from folk on the street.',
#  'the bike, looking worried.',
#  'the end of the cycle?',
#  'the last person I figured would do something like this. I mean, George, yeah,',
#  'the wall on her own. But as she raises it, the weight proves too much and she',
#  'the whole fruit. Not a third of an apple, not a half of a banana...',
#  'them the name, they just loved it.',
#  'them.',
#  'then!',
#  'there.',
#  'thing  ',
#  'this.',
#  'thought  ',
#  'thoughtfully.',
#  'to',
#  'to the first person who could make this pain go away.',
#  "together. Both dressed, different clothes. Well, I'll be in the same clothes.",
#  'unfortunately, my friendship to each of you precludes my getting',
#  "us, because it's very hard to get compliments based on your human",
#  'voice.',
#  'waffle!',
#  'want.',
#  'wash cycle. You know, she did laundry the day after she met you, everything',
#  'way',
#  'way.',
#  'wearing and they accept the compliment as if it was about them. "Nice tie."',
#  'wearing the same black and white dress as at their two previous meetings.',
#  'week.',
#  'what',
#  "who don't deserve even the privilege of the daily mail. (angry) Stuffing",
#  'with  ',
#  'with our arrangement?',
#  'with you here, but you know the sound a can makes when you open it?',
#  "woman, Christie, who stands looking at the toys. She's wearing a dress of",
#  'written on the photo.',
#  'yeah',
#  'years.',
#  'yin-yang!',
#  'you',
#  'you can do.',
#  "you're hungry enough to eat a horse.",
#  "you, but we take it. That's kind of the job of clothes; to get compliments for",
#  'you.  ',
#  'you?',
#  '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'}

# %%
header_and_footer_lines = {e for e,ct in c.items() if ct>50}

def keep_line(line):
  if line in header_and_footer_lines:
    return False
  if 'spell check' in line.lower():
    return False
  if line.startswith('[End]'):
    return False
  if line.lower().startswith('end of show'):
    return False
  if '.........' in line:
    return False
  if '---------' in line:
    return False
  if line.startswith('#'):
    return False
  if line.startswith('='):
    return False
  if line.startswith('Episode'):
    return False
  if line.lower().startswith('originally aired'):
    return False
  if line.startswith('%'):
    return False
  if line.startswith('Written by'):
    return False
  if line.startswith("Directed by"):
    return False
  if line.lower().startswith("[transcribed by"):
    return False
  if line.startswith("Broadcasted:"):
    return False
  if line.startswith("Stars:"):
    return False
  if line.startswith("Jason Alexander"):
    return False
  return True

raw_texts_filt = [[l for l in raw_text if keep_line(l)] for raw_text in raw_texts]

# %%
episode_texts = [' '.join(raw_text) for raw_text in raw_texts_filt]

# %% [markdown]
# Sometimes the lines are "JERRY:..." and some times "Jerry:...". Let's replace them all with standard capitalization.

# %%
episode_texts = [re.sub(r'([A-Za-z]+:)', lambda m: m.group(0).capitalize() , t) for t in episode_texts]

# %%
print('\n'.join(textwrap.wrap(episode_texts[16],130)))
# Out:
# LaBiosa (as Antonio). [Setting: Night club] Jerry: I'm not a foodie. I don't, "Oh, this is too rare. Oh, it's too salty." Just eat
# it and shut up. I'll eat anywhere, whatever they're having. I have eaten rotten rolls off of room service trays in hotel hallways.
# I have. It's not a joke. This is my life. I don't know, somebody left it. Why would someone poison a roll, and leave it in a
# hallway for some comic coming down at two o' clock in the morning? Why would they do that? Sometimes you go to a nice restaurant,
# they put the check in a little book. What is this? The story of the bill? "Once upon a time, there were some very hungry people.."
# What is this? A little gold tassle hanging down? Am I graduating from the restaurant? What is this about? [Setting: A restaurant]
# (Jerry, George, and Elaine are all eating at an Italian restaurant. George hasn't eaten anything) Elaine: Do you want some of
# mine? Jerry: Take some of mine. George: Why do I get pesto? Why do I think I'll like it? I keep trying to like it, like I have to
# like it. Jerry: Who said you have to like it? George: Everybody likes pesto. You walk into a restaurant, that's all you hear -
# pesto, pesto, pesto. Jerry: I don't like pesto. George: Where was pesto 10 years ago? Jerry: (Gesturing to a man) Look at that
# guy. (Elaine starts to look, but Jerry stops her) I'll bet you he's gettin' hair transplants. Any time you see a guy that age
# wearing a baseball cap, ten to one - plugs. Elaine: (Elaine turns to look at the man, trying to make it sound like they aren't
# talking about him) The thing about that painting.. is with the colors and um.. (Turns back to Jerry) Oh yeah, plugola. (George has
# started eating Elaine's food - and continues to do so) Jerry: (To Elaine) Oh, one more thing about the car. Let it warm up for a
# minute. George: That's a tough minute. It's like waiting in the shower for the conditioner to work. Jerry: I don't understand why
# he couldn't take a cab. George: Who? Jerry: Elaine is having a "houseguest." She's picking him up at the airport tonight. George:
# Kramer: Yeah. I just buzzed him in. He's on his way up.. George: He's coming up?! (Moves to the door) I'll check you out later.
# Jerry: Where are you going? George: I'm the one he wants! He's coming to settle the score. Jerry: (Trying to get George and Kramer
# out) No. You three all know each other. There's no point in me getting involved at this stage of the game. Kramer: No, he's not
# going to do anything. I guarantee it. George: Oh, the hell with it. Let him kill me. I.. (There's a knock in the hallway) Kramer:
# Antonio. In here! (Antonio enters) George: (Nervous, his voice cracks) Hey, Antonio. How's it going? (Antonio crosses over to
# George, and gives him a hug) Antonio: Three nights ago, a gas main beneath the restaurant exploded, killing five people in my
# section, including the busboy who replaced me. If I am not fired that night because of you and your thoughtless, stupid,
# insensitive remarks, it would have been me. You saved my life. (Hugs him again) George: (Trying to be modest) Ah, come on.. (The
# intercom buzzes) Elaine: (Into the intercom) Yeah? Ed: It's Eddie. Elaine: He's coming up. (Buzzes him in) He's coming up..
# Antonio: And that very same night of the accident, while looking for Pequita, I found a job in a restaurant where they pay me
# almost twice what I was making before - and when I returned to the apartment, Pequita, perhaps frightened from the explosion, had
# miraculously returned. Well, but now, I must go, for today I am starting my new and wonderful job. And I am very late. Thank you,
# thank you, thank you all. (Leaves) (Everyone ad-libs congratulations to George. Then, we hear a fight erupting from the hallway)
# Ed: Hey, watch were you're going. You almost knocked my head off! Antonio: Hey, why don't you watch where you're going, okay?
# 'Cause you bumped into me! Ed: Who do you think you're talking to, pal? Antonio: Hey, get your hands off me! Ed: Go to hell!
# (Antonio screams out profanity in Spanish, then we hear them getting into a serious fight) [Setting: Coffee shop] Jerry: He'll get
# another job. He's a busboy! George: It won't for a while. At least not until after the cast comes off. Jerry: It was that fall
# down the stairs. That's what did it. George: That's not how it happened. It's when he fell on him with his knee. Elaine: Oh, that
# was awful. Poor Antonio. (Waiter hands Elaine two bags of food to go) ..Thanks. George: So, much longer? Elaine: Till when - till
# he goes back to Seattle, or till he can feed himself? George: (Not wanting to make Elaine mad) I guess it's not important. Elaine:
# Take care of yourselves. (Leaves) George: I should probably get going too. If I don't feed Pequita by seven, she goes all over
# everything.. take it easy. Jerry: Yeah.. (Takes a bite of his sandwich as the waiter starts cleaning off the table) How ya doing?
# [Setting: Night club] Jerry: First of all, I can't believe that people actually do fight. People have fist fights in life. I can't
# really believe that we have boxing either. It's really kind of an amazing thing. To me, the problem with boxing is - you have two
# guys having a fight that have no prior argument. Why don't they have the boxers come into the ring in little cars, drive around a
# bit, have a little accident? They get out, "Didn't you see my signal?" "Look at that fender!" ..Then you'd see a real fight.

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import os

# %%
DATA_DIR = '/gdrive/My Drive/projects/seinfeldvision/corpus'
os.makedirs(DATA_DIR, exist_ok=True)

# %%
for episode_name, episode_text in tqdm_notebook(zip(episode_names, episode_texts)):
  with open(os.path.join(DATA_DIR, f'{episode_name}.txt'), 'wt') as f:
    f.write(episode_text)
len(os.listdir(DATA_DIR))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 180

# %%
with open('/gdrive/My Drive/projects/seinfeldvision/whole_corpus.txt', 'wt') as f:
  for t in episode_texts:
    f.write(t)
    f.write('\n')
